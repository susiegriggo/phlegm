# %% [markdown]
# Several of the structures have structures that were determined with NMR. These structures are normally monomers and not so good for determining what their actual state is - should be filtered out

# %%
# imports 
import pandas as pd
from Bio import SeqIO
import re
import requests
from collections import Counter
from tqdm import tqdm

# %%
df = pd.read_csv("../files/phrog_represenative_pdb_seqres_minseqid0.3_c0.7.m8", sep="\t", header=None)
df.columns = [
    "query", "target", "pident", "alnlen", "mismatch", "gapopen",
    "qstart", "qend", "tstart", "tend", "evalue", "bitscore"
]

# Load query and target lengths from FASTA files
def load_lengths(fasta_file):
    return {record.id: len(record.seq) for record in SeqIO.parse(fasta_file, "fasta")}

query_lengths = load_lengths("../files/nonsingleton_representative_sequences.fasta") # PHROG representative sequences
target_lengths = load_lengths("../files/pdb_seqres.cleaned.txt") # Sequences in the protein databank 

# Map lengths to dataframe
df["qlen"] = df["query"].map(query_lengths)
df["tlen"] = df["target"].map(target_lengths)

# Compute coverage
df["query_coverage"] = (df["qend"] - df["qstart"] + 1) / df["qlen"]
df["target_coverage"] = (df["tend"] - df["tstart"] + 1) / df["tlen"]
df['pdb'] = [re.split('_',i)[0] for i in df['target']]

# %%
# code for determining the oligomeric state

# %%
pdb_ids = list(set(df['pdb'].to_list()))

def get_experimental_method(pdb_id):
    url = f"https://data.rcsb.org/rest/v1/core/entry/{pdb_id.lower()}"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        method = data.get("exptl", [{}])[0].get("method", "Not available")
        return method
    else:
        return f"Error {response.status_code}"

# Fetch methods
results = []
for pdb_id in tqdm(pdb_ids, desc="Fetching experimental methods"):
    method = get_experimental_method(pdb_id)
    results.append({'PDB_ID': pdb_id.upper(), 'Experimental_Method': method})

# Convert to DataFrame
method_df = pd.DataFrame(results)
print(method_df)

# Optional: Save to CSV
method_df.to_csv("pdb_experimental_methods.csv", index=False)
# Out:
# Fetching experimental methods:   0%|          | 5/22234 [00:03<3:58:45,  1.55it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 16
#      14 results = []
#      15 for pdb_id in tqdm(pdb_ids, desc="Fetching experimental methods"):
# ---> 16     method = get_experimental_method(pdb_id)
#      17     results.append({'PDB_ID': pdb_id.upper(), 'Experimental_Method': method})
#      19 # Convert to DataFrame
#
# Cell In[40], line 5, in get_experimental_method(pdb_id)
#       3 def get_experimental_method(pdb_id):
#       4     url = f"https://data.rcsb.org/rest/v1/core/entry/{pdb_id.lower()}"
# ----> 5     response = requests.get(url)
#       6     if response.status_code == 200:
#       7         data = response.json()
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/requests/sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/requests/sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/requests/adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/connection.py:414, in HTTPSConnection.connect(self)
#     405 if (
#     406     not self.ca_certs
#     407     and not self.ca_cert_dir
#    (...)
#     410     and hasattr(context, "load_default_certs")
#     411 ):
#     412     context.load_default_certs()
# --> 414 self.sock = ssl_wrap_socket(
#     415     sock=conn,
#     416     keyfile=self.key_file,
#     417     certfile=self.cert_file,
#     418     key_password=self.key_password,
#     419     ca_certs=self.ca_certs,
#     420     ca_cert_dir=self.ca_cert_dir,
#     421     ca_cert_data=self.ca_cert_data,
#     422     server_hostname=server_hostname,
#     423     ssl_context=context,
#     424     tls_in_tls=tls_in_tls,
#     425 )
#     427 # If we're using all defaults and the connection
#     428 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     429 # for the host.
#     430 if (
#     431     default_ssl_context
#     432     and self.ssl_version is None
#     433     and hasattr(self.sock, "version")
#     434     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     435 ):
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/util/ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/site-packages/urllib3/util/ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/ssl.py:1041, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038         if timeout == 0.0:
#    1039             # non-blocking
#    1040             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1041         self.do_handshake()
#    1042 except (OSError, ValueError):
#    1043     self.close()
#
# File ~/miniconda3/envs/notebook_env/lib/python3.9/ssl.py:1310, in SSLSocket.do_handshake(self, block)
#    1308     if timeout == 0.0 and block:
#    1309         self.settimeout(None)
# -> 1310     self._sslobj.do_handshake()
#    1311 finally:
#    1312     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
pdb_ids
# Out:
# ['1o03',
#  '3tab',
#  '1awd',
#  '4ani',
#  '2zb2',
#  '6xc1',
#  '7ct6',
#  '8g9b',
#  '3cla',
#  '3zmo',
#  '8qmt',
#  '2ro5',
#  '3tms',
#  '3jqk',
#  '4a7s',
#  '1l85',
#  '5xr2',
#  '2vpx',
#  '7a8d',
#  '8dh5',
#  '1dg5',
#  '3ia5',
#  '5fu0',
#  '6lgm',
#  '5aqu',
#  '9g2y',
#  '1vvj',
#  '2c2a',
#  '6d15',
#  '3pyx',
#  '2dlb',
#  '6wu9',
#  '3g3w',
#  '6mtc',
#  '7doo',
#  '4s2i',
#  '9l9p',
#  '4elv',
#  '4ktq',
#  '5ijx',
#  '1kqa',
#  '5ou2',
#  '1hl5',
#  '8jlt',
#  '8bc2',
#  '7fq1',
#  '7tq1',
#  '7pld',
#  '8uqp',
#  '8h40',
#  '2kmg',
#  '6g7m',
#  '1c9d',
#  '2e6b',
#  '2a5w',
#  '3m0i',
#  '7ngh',
#  '8xqu',
#  '3dnv',
#  '8iwv',
#  '1geq',
#  '8yo3',
#  '7bni',
#  '8umt',
#  '8e7u',
#  '5rp3',
#  '1kfj',
#  '6dd7',
#  '8bav',
#  '8idd',
#  '8wdb',
#  '5mvr',
#  '8i1v',
#  '4rnp',
#  '8qdd',
#  '8gmt',
#  '8pcg',
#  '3it9',
#  '3ga6',
#  '1m6s',
#  '4lfc',
#  '7cr6',
#  '4r54',
#  '5bt0',
#  '2fzd',
#  '3hta',
#  '4kh3',
#  '1f3w',
#  '9iil',
#  '4yed',
#  '6igz',
#  '5jwt',
#  '5ndv',
#  '3sa2',
#  '6zjj',
#  '4go2',
#  '5h6l',
#  '2eii',
#  '5cdm',
#  '1mj0',
#  '3slt',
#  '4ckl',
#  '6lue',
#  '8w8l',
#  '7l0k',
#  '4rmf',
#  '5v79',
#  '5oxj',
#  '5j4b',
#  '2a69',
#  '2gyy',
#  '4r51',
#  '4c7r',
#  '8prs',
#  '2kj8',
#  '8eal',
#  '7tc1',
#  '8t8c',
#  '8g0g',
#  '6v7u',
#  '7tt6',
#  '7adc',
#  '8ou8',
#  '8k2d',
#  '7k50',
#  '7t2e',
#  '3zf3',
#  '3uzz',
#  '6qca',
#  '6wom',
#  '7mev',
#  '1xp5',
#  '5cbn',
#  '3c7u',
#  '3nvw',
#  '1uaj',
#  '1mm8',
#  '1rb3',
#  '1rx2',
#  '8jiw',
#  '6nc1',
#  '1ye3',
#  '9h3u',
#  '1qm4',
#  '3n7l',
#  '3iev',
#  '5nxn',
#  '7vyf',
#  '6soc',
#  '8f1t',
#  '8yo4',
#  '1q7c',
#  '7w4d',
#  '4d2e',
#  '3fiu',
#  '7nax',
#  '1iy2',
#  '5edd',
#  '2eiw',
#  '2wz5',
#  '6fk3',
#  '5uh8',
#  '6bzo',
#  '1m6h',
#  '3l68',
#  '5ja3',
#  '4apb',
#  '7wys',
#  '6qgd',
#  '8byv',
#  '2e4g',
#  '1wxw',
#  '4tma',
#  '2d7j',
#  '7vn3',
#  '5x21',
#  '6vx4',
#  '6n8z',
#  '8cgr',
#  '5cdn',
#  '4b0e',
#  '8ijv',
#  '1dl3',
#  '3gzp',
#  '6o13',
#  '4v5s',
#  '2f38',
#  '2prm',
#  '5h45',
#  '6iqd',
#  '4ycl',
#  '8k39',
#  '7xea',
#  '5uag',
#  '1jpn',
#  '7wao',
#  '5mmm',
#  '1g2a',
#  '7drj',
#  '2vpy',
#  '5dbh',
#  '2b2j',
#  '4iww',
#  '5afs',
#  '4dky',
#  '5j43',
#  '9d83',
#  '4s2e',
#  '4zty',
#  '4dcb',
#  '1oee',
#  '4kex',
#  '1piy',
#  '6c73',
#  '7fie',
#  '1lea',
#  '6ynd',
#  '3mzf',
#  '3ju0',
#  '4v68',
#  '6jdg',
#  '8d4v',
#  '2zhx',
#  '8f6k',
#  '4j8y',
#  '5o78',
#  '3gw1',
#  '3mrt',
#  '6z8m',
#  '5y1t',
#  '5ogt',
#  '2cfu',
#  '5olx',
#  '2fz9',
#  '7rhw',
#  '1fuy',
#  '4edt',
#  '3kre',
#  '2kbx',
#  '4en7',
#  '7loa',
#  '7oy2',
#  '7c18',
#  '2z3x',
#  '6a9w',
#  '2r6c',
#  '5w6h',
#  '6gsl',
#  '7lav',
#  '2icu',
#  '5bq2',
#  '1ltb',
#  '4v7x',
#  '8tt4',
#  '6v7w',
#  '6lfg',
#  '4az4',
#  '7ypj',
#  '4k9d',
#  '6wbh',
#  '2f4f',
#  '5g26',
#  '4w2h',
#  '5ets',
#  '7wb3',
#  '6vqx',
#  '2dds',
#  '6d17',
#  '7fs7',
#  '3ja6',
#  '1az1',
#  '1jxi',
#  '5b53',
#  '6jop',
#  '3fx4',
#  '5zeb',
#  '3tde',
#  '5owf',
#  '8f1j',
#  '1k08',
#  '2ar8',
#  '7mea',
#  '2jli',
#  '3dn5',
#  '5l8r',
#  '5b66',
#  '2yhc',
#  '1n8k',
#  '2lw5',
#  '2i6y',
#  '2w9s',
#  '8g6y',
#  '3tqz',
#  '7k55',
#  '3l93',
#  '6fqm',
#  '1cy9',
#  '5l71',
#  '3lwf',
#  '6qo4',
#  '7oe0',
#  '9fcw',
#  '7dgq',
#  '9fve',
#  '7vb7',
#  '6raj',
#  '4xmz',
#  '4myx',
#  '1oal',
#  '3c41',
#  '1lgu',
#  '8v9j',
#  '4o59',
#  '7dul',
#  '8pzv',
#  '8xyu',
#  '3v3d',
#  '1gin',
#  '6r0h',
#  '5we6',
#  '2vpw',
#  '6spr',
#  '6bat',
#  '1l17',
#  '2kkx',
#  '186l',
#  '1s8c',
#  '3iqy',
#  '6of1',
#  '4esv',
#  '5w0t',
#  '2b3t',
#  '4khy',
#  '6va8',
#  '3l7a',
#  '9cld',
#  '2ixi',
#  '4fnc',
#  '6ztn',
#  '3h7u',
#  '1ry0',
#  '1ys6',
#  '3pil',
#  '8zn4',
#  '8rj8',
#  '146l',
#  '7wva',
#  '7jt2',
#  '6ade',
#  '3j4a',
#  '2c5c',
#  '1mbu',
#  '7vy8',
#  '1oze',
#  '8vhl',
#  '7l8l',
#  '6xij',
#  '2j5n',
#  '4kwg',
#  '7ecv',
#  '3pln',
#  '3l2x',
#  '1l9z',
#  '8d3q',
#  '3mkl',
#  '6dt8',
#  '8qem',
#  '3amv',
#  '1pb1',
#  '1qrc',
#  '1srr',
#  '5nss',
#  '7paq',
#  '7y9p',
#  '1jh8',
#  '4pk0',
#  '2el7',
#  '7eh0',
#  '4w56',
#  '1fjj',
#  '7w7w',
#  '2qll',
#  '1fxi',
#  '2acr',
#  '2fgj',
#  '5ki3',
#  '8bbs',
#  '2lu5',
#  '1rk7',
#  '7ya7',
#  '8gyf',
#  '3l79',
#  '8t6h',
#  '5ndg',
#  '7rwi',
#  '3jw5',
#  '4xvn',
#  '4b4a',
#  '8w6j',
#  '3bgx',
#  '5kql',
#  '3pes',
#  '6xkc',
#  '1sxt',
#  '2o2c',
#  '1pys',
#  '6rn4',
#  '1bsp',
#  '4ecm',
#  '8ssy',
#  '4qpq',
#  '6zvn',
#  '1xk0',
#  '5mem',
#  '7q00',
#  '7a5t',
#  '4v4q',
#  '8kge',
#  '4ho8',
#  '1mjc',
#  '1hd7',
#  '6ee4',
#  '4dyr',
#  '5scc',
#  '1il2',
#  '5vk4',
#  '7pq9',
#  '1gd1',
#  '5wf0',
#  '5ftc',
#  '4n9l',
#  '7qor',
#  '6h44',
#  '7w4s',
#  '1par',
#  '7kdr',
#  '2wv6',
#  '8fov',
#  '4daf',
#  '8w5d',
#  '2x17',
#  '1ngj',
#  '3de5',
#  '7r6y',
#  '4w6j',
#  '6gdf',
#  '5h92',
#  '6ybj',
#  '6n9e',
#  '4jb8',
#  '3pfw',
#  '2rbp',
#  '5jff',
#  '7a8a',
#  '7mys',
#  '4jbw',
#  '5dgf',
#  '8c1x',
#  '7av7',
#  '1p5u',
#  '8qdy',
#  '7ai5',
#  '5ou0',
#  '5ok1',
#  '7st2',
#  '6jff',
#  '8ove',
#  '3rhj',
#  '1ucu',
#  '5aqm',
#  '6wdb',
#  '3hvx',
#  '7cvv',
#  '5kbj',
#  '9c4p',
#  '1g59',
#  '7p48',
#  '4jfb',
#  '6koo',
#  '7swk',
#  '2haj',
#  '3ecu',
#  '8b2v',
#  '8rci',
#  '8cl9',
#  '6wdk',
#  '8xm1',
#  '4q2x',
#  '2i5m',
#  '1l8p',
#  '1l56',
#  '7tt0',
#  '3ne6',
#  '2j7e',
#  '3vht',
#  '1b3g',
#  '4dfp',
#  '6gvr',
#  '2lxn',
#  '6ruh',
#  '7vn4',
#  '5oka',
#  '2jl9',
#  '1pvv',
#  '7s87',
#  '6vyx',
#  '2iv0',
#  '5cdo',
#  '2zon',
#  '4r6j',
#  '1z7w',
#  '4rph',
#  '1l15',
#  '5ok7',
#  '1n9k',
#  '8tbt',
#  '2exv',
#  '4yqp',
#  '4feb',
#  '2vhc',
#  '8eqm',
#  '1zpq',
#  '5vfu',
#  '8tch',
#  '9arj',
#  '8hgf',
#  '1l79',
#  '1d9z',
#  '6h3c',
#  '107l',
#  '7ye1',
#  '1qki',
#  '3sg1',
#  '6ecq',
#  '8irm',
#  '1e83',
#  '4xer',
#  '7nkz',
#  '5jt4',
#  '3ild',
#  '4c5m',
#  '7c5h',
#  '5uyc',
#  '1se7',
#  '6gov',
#  '1kl1',
#  '7xyj',
#  '8eg8',
#  '7zqe',
#  '4dww',
#  '8egb',
#  '2dr5',
#  '8bl2',
#  '6gi7',
#  '2wa8',
#  '8st8',
#  '6fku',
#  '4khs',
#  '7uji',
#  '3cgy',
#  '2xd1',
#  '5gld',
#  '4zx6',
#  '2cuz',
#  '9aux',
#  '7rw7',
#  '9e5e',
#  '4v78',
#  '6n1m',
#  '7qnl',
#  '4zz7',
#  '3g0u',
#  '1tqg',
#  '8q5a',
#  '2ob9',
#  '7waa',
#  '4fcw',
#  '2ima',
#  '8srv',
#  '8aha',
#  '4xem',
#  '4u2v',
#  '5mad',
#  '8abz',
#  '6hhz',
#  '8jlm',
#  '7fd4',
#  '7kyf',
#  '8d5i',
#  '4ore',
#  '4zf4',
#  '2b82',
#  '1wuj',
#  '4wim',
#  '2whi',
#  '2gmu',
#  '6rtl',
#  '2qf3',
#  '4zyx',
#  '4wrx',
#  '8yke',
#  '5vly',
#  '1g4a',
#  '4r7o',
#  '6n6n',
#  '1a80',
#  '7lqb',
#  '6of7',
#  '1u3t',
#  '6zob',
#  '2v1z',
#  '5rox',
#  '8xmh',
#  '7xa0',
#  '7nsp',
#  '6m5o',
#  '1btl',
#  '1ubr',
#  '8yd3',
#  '4ud2',
#  '7nhl',
#  '7xoo',
#  '8wgh',
#  '3s82',
#  '7jn9',
#  '6ran',
#  '6pf6',
#  '4y4o',
#  '9dp1',
#  '6oc0',
#  '6cw7',
#  '6b5e',
#  '1xfj',
#  '7o7v',
#  '8yup',
#  '3uwa',
#  '8t83',
#  '5lrd',
#  '4v37',
#  '3m4h',
#  '3gzq',
#  '6cey',
#  '4tud',
#  '8pvg',
#  '2aqn',
#  '3ar7',
#  '2j5t',
#  '1mpn',
#  '6dt1',
#  '3v0a',
#  '8btk',
#  '6mrh',
#  '1hzc',
#  '8q0g',
#  '1xf0',
#  '6blj',
#  '2dui',
#  '3b2g',
#  '5eyp',
#  '5lw2',
#  '6pyt',
#  '1l43',
#  '4q3m',
#  '4oud',
#  '1sh7',
#  '1l5l',
#  '4v8x',
#  '2rg1',
#  '1n7g',
#  '6og3',
#  '6qrf',
#  '4axh',
#  '4zu6',
#  '4i46',
#  '5eb3',
#  '3nyr',
#  '1cde',
#  '5twk',
#  '6qyy',
#  '8uaj',
#  '6eri',
#  '3jbu',
#  '2x56',
#  '7bt2',
#  '4yqq',
#  '1vix',
#  '1enf',
#  '2jgr',
#  '2ob7',
#  '1cx9',
#  '7ye4',
#  '6b1y',
#  '5icd',
#  '4xse',
#  '4j89',
#  '8dvh',
#  '3ilo',
#  '8fyp',
#  '1l72',
#  '1mi3',
#  '1p9r',
#  '8dwj',
#  '1hza',
#  '7b8s',
#  '4kjj',
#  '1t17',
#  '8f06',
#  '8giu',
#  '8jan',
#  '6b4v',
#  '5vjf',
#  '4bxe',
#  '3itk',
#  '8wfq',
#  '4yqa',
#  '1riq',
#  '4v69',
#  '5vxy',
#  '3zf2',
#  '8cga',
#  '4lnk',
#  '8evp',
#  '1evf',
#  '4arl',
#  '1f8f',
#  '7seh',
#  '6u5b',
#  '3pnb',
#  '7pzz',
#  '8pcr',
#  '2oam',
#  '5t4j',
#  '4v9b',
#  '8ire',
#  '4rtf',
#  '7nho',
#  '4dy3',
#  '5bne',
#  '1xeo',
#  '8a01',
#  '6ujd',
#  '6iol',
#  '1mul',
#  '1spd',
#  '2lmc',
#  '3pn8',
#  '4z7z',
#  '5z2k',
#  '7a7s',
#  '7pis',
#  '8rwr',
#  '8ovg',
#  '5if9',
#  '1upi',
#  '3gcn',
#  '1xcb',
#  '1dr5',
#  '6p4h',
#  '6vz5',
#  '6txp',
#  '4ewj',
#  '5aqs',
#  '1dde',
#  '1duv',
#  '4cc6',
#  '2out',
#  '6u49',
#  '2h6v',
#  '8b9y',
#  '5mgi',
#  '3cmc',
#  '1nbo',
#  '7as9',
#  '2dq6',
#  '7tm7',
#  '8ir8',
#  '8jdl',
#  '1qdl',
#  '4r1r',
#  '6mn2',
#  '7b8t',
#  '1oxs',
#  '6ea2',
#  '4dbx',
#  '4m8j',
#  '9cl9',
#  '4o7v',
#  '1d3g',
#  '4kpe',
#  '3d80',
#  '7nst',
#  '1v3r',
#  '3q9n',
#  '2z99',
#  '2i6g',
#  '5wj1',
#  '3pih',
#  '7zq6',
#  '4hyt',
#  '8zyj',
#  '5x6f',
#  '3n3b',
#  '2xco',
#  '4xvp',
#  '2via',
#  '6qz0',
#  '1a7k',
#  '5uyd',
#  '2ch4',
#  '2fvo',
#  '6d7h',
#  '4git',
#  '4yu1',
#  '2qdl',
#  '1xtb',
#  '2j77',
#  '1w48',
#  '6bfz',
#  '2gel',
#  '1w8x',
#  '4p70',
#  '2hyd',
#  '1g1l',
#  '3wby',
#  '1g06',
#  '1wc0',
#  '4ug0',
#  '7p6z',
#  '1lba',
#  '4rr0',
#  '6rr4',
#  '5czf',
#  '6r5w',
#  '7c0p',
#  '4v4o',
#  '5uwx',
#  '4wmx',
#  '8r2o',
#  '5nx0',
#  '6sog',
#  '7ens',
#  '4qhp',
#  '9ha1',
#  '1atr',
#  '1t36',
#  '4v5z',
#  '1lau',
#  '5mz8',
#  '2gzg',
#  '3j9q',
#  '4jq2',
#  '1h5t',
#  '1mrq',
#  '6bot',
#  '1njs',
#  '9imh',
#  '6yt5',
#  '7w7v',
#  '4kr5',
#  '5wyr',
#  '3g8m',
#  '5br8',
#  '7ua7',
#  '2aq2',
#  '4csw',
#  '6go8',
#  '4tss',
#  '5da8',
#  '1io1',
#  '3kvn',
#  '4kl8',
#  '6rpd',
#  '5vcp',
#  '2qk8',
#  '1l59',
#  '6pmi',
#  '3hef',
#  '4jom',
#  '4xmy',
#  '6hhx',
#  '2p5r',
#  '3gtt',
#  '1c79',
#  '4gki',
#  '9bh0',
#  '1frr',
#  '8h2u',
#  '2xpe',
#  '6qyq',
#  '5a2q',
#  '8xpd',
#  '3qex',
#  '3bcj',
#  '4wxg',
#  '1osm',
#  '3jr6',
#  '1beu',
#  '6smw',
#  '4i3u',
#  '9fus',
#  '1l4i',
#  '6kiy',
#  '4wni',
#  '5ogz',
#  '6yhs',
#  '4ep1',
#  '1zau',
#  '6kg2',
#  '4pd8',
#  '8qe0',
#  '1c77',
#  '4lrj',
#  '5cog',
#  '8bpp',
#  '5ixl',
#  '3h9n',
#  '4h7c',
#  '1s0f',
#  '6jes',
#  '3iov',
#  '4bil',
#  '2zr2',
#  '1nnv',
#  '3huk',
#  '1bxs',
#  '3nz2',
#  '4gl4',
#  '4k7h',
#  '2ntg',
#  '9gsj',
#  '6cux',
#  '8hih',
#  '4jpb',
#  '3h99',
#  '8ps5',
#  '8wda',
#  '6yv5',
#  '4uxz',
#  '9cg6',
#  '8f5t',
#  '6y2z',
#  '7kh8',
#  '2fpt',
#  '1jc1',
#  '8sy9',
#  '5jtq',
#  '8y5h',
#  '7d4x',
#  '1hzw',
#  '2wa9',
#  '1l35',
#  '6z4n',
#  '9gct',
#  '2k8d',
#  '3g30',
#  '8i3i',
#  '5ftb',
#  '2orw',
#  '8yo9',
#  '8qwj',
#  '8ifx',
#  '6qrd',
#  '2pfl',
#  '8e8m',
#  '6fzh',
#  '3cyn',
#  '4apa',
#  '2inr',
#  '4qpo',
#  '3qns',
#  '8g31',
#  '7odb',
#  '1zo1',
#  '5o5j',
#  '3ktx',
#  '1bs2',
#  '5in5',
#  '8vbx',
#  '3ssy',
#  '2ai8',
#  '4pl9',
#  '3qiz',
#  '8f72',
#  '4wqu',
#  '1xnh',
#  '8dqw',
#  '4ue6',
#  '2j45',
#  '4du4',
#  '1ihy',
#  '8fon',
#  '6o9s',
#  '1tx9',
#  '6mtk',
#  '6h01',
#  '5evz',
#  '1i1n',
#  '7r3b',
#  '2pp6',
#  '7jz3',
#  ...]

# %%
# then once this has finished - use this df to filter out structures that were only determined using NMR
# Out:
# [{'PDB_ID': '1O03', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '3TAB', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '1AWD', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '4ANI', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '2ZB2', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '6XC1', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '7CT6', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '8G9B', 'Experimental_Method': 'ELECTRON MICROSCOPY'},
#  {'PDB_ID': '3CLA', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '3ZMO', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '8QMT', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '2RO5', 'Experimental_Method': 'SOLUTION NMR'},
#  {'PDB_ID': '3TMS', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '3JQK', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '4A7S', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '1L85', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '5XR2', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '2VPX', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '7A8D', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '8DH5', 'Experimental_Method': 'X-RAY DIFFRACTION'},
#  {'PDB_ID': '1DG5', 'Experimental_Method': 'X-RAY DIFFRACTION'}]
